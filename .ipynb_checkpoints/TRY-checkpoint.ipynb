# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
import statsmodels.api as sm
from statsmodels.nonparametric.kde import KDEUnivariate
from statsmodels.nonparametric import smoothers_lowess
from pandas import Series, DataFrame
from patsy import dmatrices
from sklearn import datasets, svm

# %%
df = pd.read_excel("AirQualityUCI.xlsx")
df = df.drop(df.index[0:6])
df
# Out:
#            Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)   C6H6(GT)  \
# 6    2004-03-11  00:00:00     1.2  1185.000000        31   3.624399
# 7    2004-03-11  01:00:00     1.0  1136.250000        31   3.326677
# 8    2004-03-11  02:00:00     0.9  1094.000000        24   2.339416
# 9    2004-03-11  03:00:00     0.6  1009.750000        19   1.696658
# 10   2004-03-11  04:00:00  -200.0  1011.000000        14   1.293620
# 11   2004-03-11  05:00:00     0.7  1066.000000         8   1.133431
# 12   2004-03-11  06:00:00     0.7  1051.750000        16   1.603768
# 13   2004-03-11  07:00:00     1.1  1144.000000        29   3.243618
# 14   2004-03-11  08:00:00     2.0  1333.250000        64   8.013773
# 15   2004-03-11  09:00:00     2.2  1351.000000        87   9.540643
# 16   2004-03-11  10:00:00     1.7  1233.250000        77   6.335782
# 17   2004-03-11  11:00:00     1.5  1178.750000        43   4.971584
# 18   2004-03-11  12:00:00     1.6  1236.000000        61   5.216919
# ...

# %%
df.isnull().values.any()
#df.isnull().sum().sum() Above method is faster
# Out:
# False

# %%
df=df.rename(columns = {'CO(GT)':'CO','PT08.S1(CO)':'PT08CO','NMHC(GT)':'NHMC','C6H6(GT)':'C6H6','PT08.S2(NMHC)':'PT08NMHC','NOx(GT)':'NOx','PT08.S3(NOx)':'PT08NOx','NO2(GT)':'NO2','PT08.S4(NO2)':'PT08NO2','PT08.S5(O3)':'PT08O3'})

# %%
df
# Out:
#            Date      Time     CO       PT08CO  NHMC       C6H6     PT08NMHC  \
# 6    2004-03-11  00:00:00    1.2  1185.000000    31   3.624399   689.500000
# 7    2004-03-11  01:00:00    1.0  1136.250000    31   3.326677   672.000000
# 8    2004-03-11  02:00:00    0.9  1094.000000    24   2.339416   608.500000
# 9    2004-03-11  03:00:00    0.6  1009.750000    19   1.696658   560.750000
# 10   2004-03-11  04:00:00 -200.0  1011.000000    14   1.293620   526.750000
# 11   2004-03-11  05:00:00    0.7  1066.000000     8   1.133431   512.000000
# 12   2004-03-11  06:00:00    0.7  1051.750000    16   1.603768   553.250000
# 13   2004-03-11  07:00:00    1.1  1144.000000    29   3.243618   667.000000
# 14   2004-03-11  08:00:00    2.0  1333.250000    64   8.013773   899.750000
# 15   2004-03-11  09:00:00    2.2  1351.000000    87   9.540643   960.250000
# 16   2004-03-11  10:00:00    1.7  1233.250000    77   6.335782   827.250000
# ...

# %%
len(df.T)
len(df.CO)
# Out:
# 9351

# %%
fig = plt.figure(figsize=(16,14), dpi=160)
a = 0.2
# Step 1
ax1 = fig.add_subplot(741)
df.CO.value_counts().plot(kind='bar', color="blue", alpha=a)
ax1.set_xlim(0,len(df.CO.value_counts())/5)
plt.title("CO")
